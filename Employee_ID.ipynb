# %%
import numpy as np

# %%
import pandas as pd

# %%
np.random.seed(42)

# %%
employee_ids=[f"EMP_{i:03d}"for i in range (1,31)]
dates=pd.date_range(start="2025-07-01",periods=30,freq="D")

# %%
employee_ids
# Out:
# ['EMP_001',
#  'EMP_002',
#  'EMP_003',
#  'EMP_004',
#  'EMP_005',
#  'EMP_006',
#  'EMP_007',
#  'EMP_008',
#  'EMP_009',
#  'EMP_010',
#  'EMP_011',
#  'EMP_012',
#  'EMP_013',
#  'EMP_014',
#  'EMP_015',
#  'EMP_016',
#  'EMP_017',
#  'EMP_018',
#  'EMP_019',
#  'EMP_020',
#  'EMP_021',
#  'EMP_022',
#  'EMP_023',
#  'EMP_024',
#  'EMP_025',
#  'EMP_026',
#  'EMP_027',
#  'EMP_028',
#  'EMP_029',
#  'EMP_030']

# %%
print(dates)
# Out:
# DatetimeIndex(['2025-07-01', '2025-07-02', '2025-07-03', '2025-07-04',
#                '2025-07-05', '2025-07-06', '2025-07-07', '2025-07-08',
#                '2025-07-09', '2025-07-10', '2025-07-11', '2025-07-12',
#                '2025-07-13', '2025-07-14', '2025-07-15', '2025-07-16',
#                '2025-07-17', '2025-07-18', '2025-07-19', '2025-07-20',
#                '2025-07-21', '2025-07-22', '2025-07-23', '2025-07-24',
#                '2025-07-25', '2025-07-26', '2025-07-27', '2025-07-28',
#                '2025-07-29', '2025-07-30'],
#               dtype='datetime64[ns]', freq='D')

# %%
data={
    "Date":np.tile(dates,len(employee_ids)),
    "Employee_ID":np.repeat(employee_ids,len(dates)),
    "Working_Hours":np.random.uniform(4,10,size=len(dates)*len(employee_ids)).round(2)
}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#           Date Employee_ID  Working_Hours
# 0   2025-07-01     EMP_001           6.25
# 1   2025-07-02     EMP_001           9.70
# 2   2025-07-03     EMP_001           8.39
# 3   2025-07-04     EMP_001           7.59
# 4   2025-07-05     EMP_001           4.94
# ..         ...         ...            ...
# 895 2025-07-26     EMP_030           5.23
# 896 2025-07-27     EMP_030           5.76
# 897 2025-07-28     EMP_030           9.38
# 898 2025-07-29     EMP_030           4.08
# 899 2025-07-30     EMP_030           4.51
#
# [900 rows x 3 columns]

# %%
df.to_csv("employee_working_hours.csv",index=False)

# %%
df_csv = pd.read_csv("employee_working_hours.csv")

# %%
df_csv
# Out:
#            Date Employee_ID  Working_Hours
# 0    2025-07-01     EMP_001           6.25
# 1    2025-07-02     EMP_001           9.70
# 2    2025-07-03     EMP_001           8.39
# 3    2025-07-04     EMP_001           7.59
# 4    2025-07-05     EMP_001           4.94
# ..          ...         ...            ...
# 895  2025-07-26     EMP_030           5.23
# 896  2025-07-27     EMP_030           5.76
# 897  2025-07-28     EMP_030           9.38
# 898  2025-07-29     EMP_030           4.08
# 899  2025-07-30     EMP_030           4.51
#
# [900 rows x 3 columns]

# %%
print(df_csv.head())
print(df_csv.describe())
print(df_csv["Employee_ID"].nunique())
# Out:
#          Date Employee_ID  Working_Hours
# 0  2025-07-01     EMP_001           6.25
# 1  2025-07-02     EMP_001           9.70
# 2  2025-07-03     EMP_001           8.39
# 3  2025-07-04     EMP_001           7.59
# 4  2025-07-05     EMP_001           4.94
#        Working_Hours
# count     900.000000
# mean        6.954233
# std         1.762088
# min         4.030000
# 25%         5.387500
# 50%         7.010000
# 75%         8.490000
# max        10.000000
# 30

# %%
total_hours=df_csv.groupby("Employee_ID")["Working_Hours"].sum().sort_values(ascending=False)
print(total_hours)
# Out:
# Employee_ID
# EMP_009    228.84
# EMP_018    226.10
# EMP_017    225.95
# EMP_014    224.92
# EMP_027    220.85
# EMP_025    214.07
# EMP_026    212.33
# EMP_016    211.56
# EMP_007    210.91
# EMP_010    210.88
# EMP_008    210.81
# EMP_011    210.77
# EMP_028    209.51
# EMP_019    209.42
# EMP_002    209.37
# EMP_004    208.46
# EMP_013    207.72
# EMP_003    206.79
# EMP_015    206.67
# EMP_024    204.46
# EMP_006    204.29
# EMP_023    203.64
# EMP_005    202.07
# EMP_022    200.73
# EMP_020    199.91
# EMP_029    199.89
# EMP_001    198.96
# EMP_012    196.52
# EMP_021    192.18
# EMP_030    190.23
# Name: Working_Hours, dtype: float64

# %%
avg_daily = df.groupby("Employee_ID")["Working_Hours"].mean()
print(avg_daily)
# Out:
# Employee_ID
# EMP_001    6.632000
# EMP_002    6.979000
# EMP_003    6.893000
# EMP_004    6.948667
# EMP_005    6.735667
# EMP_006    6.809667
# EMP_007    7.030333
# EMP_008    7.027000
# EMP_009    7.628000
# EMP_010    7.029333
# EMP_011    7.025667
# EMP_012    6.550667
# EMP_013    6.924000
# EMP_014    7.497333
# EMP_015    6.889000
# EMP_016    7.052000
# EMP_017    7.531667
# EMP_018    7.536667
# EMP_019    6.980667
# EMP_020    6.663667
# EMP_021    6.406000
# EMP_022    6.691000
# EMP_023    6.788000
# EMP_024    6.815333
# EMP_025    7.135667
# EMP_026    7.077667
# EMP_027    7.361667
# EMP_028    6.983667
# EMP_029    6.663000
# EMP_030    6.341000
# Name: Working_Hours, dtype: float64

# %%
threshold_low=5
threshold_high=9
df_csv["low_Hour_flag"]=df_csv["Working_Hours"]<threshold_low
df_csv["high_Hour_flag"]=df_csv["Working_Hours"]>threshold_high

# %%
print(df_csv[df_csv["low_Hour_flag"]])
print(df_csv[df_csv["high_Hour_flag"]])
# Out:
#            Date Employee_ID  Working_Hours  low_Hour_flag  high_Hour_flag
# 4    2025-07-05     EMP_001           4.94           True           False
# 5    2025-07-06     EMP_001           4.94           True           False
# 6    2025-07-07     EMP_001           4.35           True           False
# 10   2025-07-11     EMP_001           4.12           True           False
# 21   2025-07-22     EMP_001           4.84           True           False
# ..          ...         ...            ...            ...             ...
# 882  2025-07-13     EMP_030           4.12           True           False
# 883  2025-07-14     EMP_030           4.62           True           False
# 888  2025-07-19     EMP_030           4.60           True           False
# 898  2025-07-29     EMP_030           4.08           True           False
# 899  2025-07-30     EMP_030           4.51           True           False
#
# [170 rows x 5 columns]
#            Date Employee_ID  Working_Hours  low_Hour_flag  high_Hour_flag
# 1    2025-07-02     EMP_001           9.70          False            True
# 7    2025-07-08     EMP_001           9.20          False            True
# 11   2025-07-12     EMP_001           9.82          False            True
# 33   2025-07-04     EMP_002           9.69          False            True
# 34   2025-07-05     EMP_002           9.79          False            True
# ..          ...         ...            ...            ...             ...
# 853  2025-07-14     EMP_029           9.39          False            True
# 868  2025-07-29     EMP_029           9.17          False            True
# 869  2025-07-30     EMP_029           9.68          False            True
# 891  2025-07-22     EMP_030           9.13          False            True
# 897  2025-07-28     EMP_030           9.38          False            True
#
# [151 rows x 5 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
top10=total_hours.head(10)
plt.figure(figsize=(10,5))
sns.barplot(x=top10.index,y=top10.values)
plt.xticks(rotation=45)
plt.title("Top 10 Employees By Total Working Hours")
plt.ylabel("Hours")
plt.tight_layout()
plt.show()
